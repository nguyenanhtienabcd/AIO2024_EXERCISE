# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyenanhtienabcd/AIO2024_EXERCISE/blob/feature%2FMODULE9-WEEK2/m09w02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chuyển text thành ảnh

# %% [markdown]
# ### Prepare data, process text

# %%
# tải bộ dữ liệu về
# !gdown 1JJjMiNieTz7xYs6UeVqd02M3DW4fnEfU
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1JJjMiNieTz7xYs6UeVqd02M3DW4fnEfU
# From (redirected): https://drive.google.com/uc?id=1JJjMiNieTz7xYs6UeVqd02M3DW4fnEfU&confirm=t&uuid=eda13bba-596a-4551-bc78-360932379056
# To: /content/cvpr2016_flowers.zip
# 100% 351M/351M [00:01<00:00, 218MB/s]

# %%
# !unzip /content/cvpr2016_flowers.zip
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: content/cvpr2016_flowers/images/image_02041.jpg
#   inflating: content/cvpr2016_flowers/images/image_06550.jpg
#   inflating: content/cvpr2016_flowers/images/image_00556.jpg
#   inflating: content/cvpr2016_flowers/images/image_05695.jpg
#   inflating: content/cvpr2016_flowers/images/image_02732.jpg
#   inflating: content/cvpr2016_flowers/images/image_00112.jpg
#   inflating: content/cvpr2016_flowers/images/image_03424.jpg
#   inflating: content/cvpr2016_flowers/images/image_03702.jpg
#   inflating: content/cvpr2016_flowers/images/image_01316.jpg
#   inflating: content/cvpr2016_flowers/images/image_03391.jpg
#   inflating: content/cvpr2016_flowers/images/image_02503.jpg
#   inflating: content/cvpr2016_flowers/images/image_05044.jpg
#   inflating: content/cvpr2016_flowers/images/image_01633.jpg
#   inflating: content/cvpr2016_flowers/images/image_05305.jpg
#   inflating: content/cvpr2016_flowers/images/image_02522.jpg
#   inflating: content/cvpr2016_flowers/images/image_06127.jpg
#   inflating: content/cvpr2016_flowers/images/image_03132.jpg
#   inflating: content/cvpr2016_flowers/images/image_04841.jpg
#   inflating: content/cvpr2016_flowers/images/image_05095.jpg
#   inflating: content/cvpr2016_flowers/images/image_02178.jpg
#   inflating: content/cvpr2016_flowers/images/image_05775.jpg
#   inflating: content/cvpr2016_flowers/images/image_02515.jpg
#   inflating: content/cvpr2016_flowers/images/image_03228.jpg
#   inflating: content/cvpr2016_flowers/images/image_06053.jpg
#   inflating: content/cvpr2016_flowers/images/image_02371.jpg
#   inflating: content/cvpr2016_flowers/images/image_06268.jpg
#   inflating: content/cvpr2016_flowers/images/image_05062.jpg
#   inflating: content/cvpr2016_flowers/images/image_02480.jpg
#   inflating: content/cvpr2016_flowers/images/image_00987.jpg
#   inflating: content/cvpr2016_flowers/images/image_07778.jpg
#   inflating: content/cvpr2016_flowers/images/image_06757.jpg
#   inflating: content/cvpr2016_flowers/images/image_01942.jpg
#   inflating: content/cvpr2016_flowers/images/image_00368.jpg
#   inflating: content/cvpr2016_flowers/images/image_00727.jpg
#   inflating: content/cvpr2016_flowers/images/image_00759.jpg
#   inflating: content/cvpr2016_flowers/images/image_03193.jpg
#   inflating: content/cvpr2016_flowers/images/image_04308.jpg
#   inflating: content/cvpr2016_flowers/images/image_05637.jpg
#   inflating: content/cvpr2016_flowers/images/image_05090.jpg
#   inflating: content/cvpr2016_flowers/images/image_05493.jpg
#   inflating: content/cvpr2016_flowers/images/image_03634.jpg
#   inflating: content/cvpr2016_flowers/images/image_07978.jpg
#   inflating: content/cvpr2016_flowers/images/image_06689.jpg
#   inflating: content/cvpr2016_flowers/images/image_05269.jpg
#   inflating: content/cvpr2016_flowers/images/image_07336.jpg
#   inflating: content/cvpr2016_flowers/images/image_06642.jpg
#   inflating: content/cvpr2016_flowers/images/image_06832.jpg
#   inflating: content/cvpr2016_flowers/images/image_03539.jpg
#   inflating: content/cvpr2016_flowers/images/image_06156.jpg
#   inflating: content/cvpr2016_flowers/images/image_07958.jpg
#   inflating: content/cvpr2016_flowers/images/image_06784.jpg
#   inflating: content/cvpr2016_flowers/images/image_00075.jpg
#   inflating: content/cvpr2016_flowers/images/image_04452.jpg
#   inflating: content/cvpr2016_flowers/images/image_00090.jpg
#   inflating: content/cvpr2016_flowers/images/image_06849.jpg
#   inflating: content/cvpr2016_flowers/images/image_06735.jpg
#   inflating: content/cvpr2016_flowers/images/image_07194.jpg
#   inflating: content/cvpr2016_flowers/images/image_02276.jpg
#   inflating: content/cvpr2016_flowers/images/image_06375.jpg
#   inflating: content/cvpr2016_flowers/images/image_02385.jpg
#   inflating: content/cvpr2016_flowers/images/image_05302.jpg
#   inflating: content/cvpr2016_flowers/images/image_05148.jpg
#   inflating: content/cvpr2016_flowers/images/image_00307.jpg
#   inflating: content/cvpr2016_flowers/images/image_02233.jpg
#   inflating: content/cvpr2016_flowers/images/image_02347.jpg
#   inflating: content/cvpr2016_flowers/images/image_00260.jpg
#   inflating: content/cvpr2016_flowers/images/image_05124.jpg
#   inflating: content/cvpr2016_flowers/images/image_02619.jpg
#   inflating: content/cvpr2016_flowers/images/image_01958.jpg
#   inflating: content/cvpr2016_flowers/images/image_04251.jpg
#   inflating: content/cvpr2016_flowers/images/image_03568.jpg
#   inflating: content/cvpr2016_flowers/images/image_00468.jpg
#   inflating: content/cvpr2016_flowers/images/image_04822.jpg
#   inflating: content/cvpr2016_flowers/images/image_01507.jpg
#   inflating: content/cvpr2016_flowers/images/image_03809.jpg
#   inflating: content/cvpr2016_flowers/images/image_06610.jpg
#   inflating: content/cvpr2016_flowers/images/image_06408.jpg
#   inflating: content/cvpr2016_flowers/images/image_02378.jpg
#   inflating: content/cvpr2016_flowers/images/image_01051.jpg
#   inflating: content/cvpr2016_flowers/images/image_00592.jpg
#   inflating: content/cvpr2016_flowers/images/image_06107.jpg
#   inflating: content/cvpr2016_flowers/images/image_00017.jpg
#   inflating: content/cvpr2016_flowers/images/image_03104.jpg
#   inflating: content/cvpr2016_flowers/images/image_00688.jpg
#   inflating: content/cvpr2016_flowers/images/image_03968.jpg
#   inflating: content/cvpr2016_flowers/images/image_02362.jpg
#   inflating: content/cvpr2016_flowers/images/image_00637.jpg
#   inflating: content/cvpr2016_flowers/images/image_02913.jpg
#   inflating: content/cvpr2016_flowers/images/image_05246.jpg
#   inflating: content/cvpr2016_flowers/images/image_04737.jpg
#   inflating: content/cvpr2016_flowers/images/image_05749.jpg
#   inflating: content/cvpr2016_flowers/images/image_04648.jpg
#   inflating: content/cvpr2016_flowers/images/image_01704.jpg
#   inflating: content/cvpr2016_flowers/images/image_02072.jpg
#   inflating: content/cvpr2016_flowers/images/image_04620.jpg
#   inflating: content/cvpr2016_flowers/images/image_01139.jpg
#   inflating: content/cvpr2016_flowers/images/image_02389.jpg
#   inflating: content/cvpr2016_flowers/images/image_01498.jpg
#   inflating: content/cvpr2016_flowers/images/image_01445.jpg
#   inflating: content/cvpr2016_flowers/images/image_04933.jpg
#   inflating: content/cvpr2016_flowers/images/image_07342.jpg
#   inflating: content/cvpr2016_flowers/images/image_06702.jpg
#   inflating: content/cvpr2016_flowers/images/image_03547.jpg
#   inflating: content/cvpr2016_flowers/images/image_07907.jpg
#   inflating: content/cvpr2016_flowers/images/image_04134.jpg
#   inflating: content/cvpr2016_flowers/images/image_06236.jpg
#   inflating: content/cvpr2016_flowers/images/image_03738.jpg
#   inflating: content/cvpr2016_flowers/images/image_03489.jpg
#   inflating: content/cvpr2016_flowers/images/image_08025.jpg
#   inflating: content/cvpr2016_flowers/images/image_07692.jpg
#   inflating: content/cvpr2016_flowers/images/image_00671.jpg
#   inflating: content/cvpr2016_flowers/images/image_05702.jpg
#   inflating: content/cvpr2016_flowers/images/image_05295.jpg
#   inflating: content/cvpr2016_flowers/images/image_01846.jpg
#   inflating: content/cvpr2016_flowers/images/image_03659.jpg
#   inflating: content/cvpr2016_flowers/images/image_00310.jpg
#   inflating: content/cvpr2016_flowers/images/image_05238.jpg
#   inflating: content/cvpr2016_flowers/images/image_00525.jpg
#   inflating: content/cvpr2016_flowers/images/image_03465.jpg
#   inflating: content/cvpr2016_flowers/images/image_08096.jpg
#   inflating: content/cvpr2016_flowers/images/image_06291.jpg
#   inflating: content/cvpr2016_flowers/images/image_06973.jpg
#   inflating: content/cvpr2016_flowers/images/image_03917.jpg
#   inflating: content/cvpr2016_flowers/images/image_04914.jpg
#   inflating: content/cvpr2016_flowers/images/image_04532.jpg
#   inflating: content/cvpr2016_flowers/images/image_06907.jpg
#   inflating: content/cvpr2016_flowers/images/image_04345.jpg
#   inflating: content/cvpr2016_flowers/images/image_05177.jpg
#   inflating: content/cvpr2016_flowers/images/image_04007.jpg
#   inflating: content/cvpr2016_flowers/images/image_00404.jpg
#   inflating: content/cvpr2016_flowers/images/image_05494.jpg
#   inflating: content/cvpr2016_flowers/images/image_04287.jpg
#   inflating: content/cvpr2016_flowers/images/image_03297.jpg
#   inflating: content/cvpr2016_flowers/images/image_02010.jpg
#   inflating: content/cvpr2016_flowers/images/image_01559.jpg
#   inflating: content/cvpr2016_flowers/images/image_06162.jpg
#   inflating: content/cvpr2016_flowers/images/image_03523.jpg
#   inflating: content/cvpr2016_flowers/images/image_06977.jpg
#   inflating: content/cvpr2016_flowers/images/image_08067.jpg
#   inflating: content/cvpr2016_flowers/images/image_06056.jpg
#   inflating: content/cvpr2016_flowers/images/image_06841.jpg
#   inflating: content/cvpr2016_flowers/images/image_04527.jpg
#   inflating: content/cvpr2016_flowers/images/image_06231.jpg
#   inflating: content/cvpr2016_flowers/images/image_02544.jpg
#   inflating: content/cvpr2016_flowers/images/image_00284.jpg
#   inflating: content/cvpr2016_flowers/images/image_05228.jpg
#   inflating: content/cvpr2016_flowers/images/image_06133.jpg
#   inflating: content/cvpr2016_flowers/images/image_08085.jpg
#   inflating: content/cvpr2016_flowers/images/image_07123.jpg
#   inflating: content/cvpr2016_flowers/images/image_00999.jpg
#   inflating: content/cvpr2016_flowers/images/image_00364.jpg
#   inflating: content/cvpr2016_flowers/images/image_03755.jpg
#   inflating: content/cvpr2016_flowers/images/image_04410.jpg
#   inflating: content/cvpr2016_flowers/images/image_03179.jpg
#   inflating: content/cvpr2016_flowers/images/image_07372.jpg
#   inflating: content/cvpr2016_flowers/images/image_05635.jpg
#   inflating: content/cvpr2016_flowers/images/image_02035.jpg
#   inflating: content/cvpr2016_flowers/images/image_03748.jpg
#   inflating: content/cvpr2016_flowers/images/image_03428.jpg
#   inflating: content/cvpr2016_flowers/images/image_03333.jpg
#   inflating: content/cvpr2016_flowers/images/image_07127.jpg
#   inflating: content/cvpr2016_flowers/images/image_04151.jpg
#   inflating: content/cvpr2016_flowers/images/image_01328.jpg
#   inflating: content/cvpr2016_flowers/images/image_01825.jpg
#   inflating: content/cvpr2016_flowers/images/image_06509.jpg
#   inflating: content/cvpr2016_flowers/images/image_05815.jpg
#   inflating: content/cvpr2016_flowers/images/image_05946.jpg
#   inflating: content/cvpr2016_flowers/images/image_01574.jpg
#   inflating: content/cvpr2016_flowers/images/image_01159.jpg
#   inflating: content/cvpr2016_flowers/images/image_07121.jpg
#   inflating: content/cvpr2016_flowers/images/image_00432.jpg
#   inflating: content/cvpr2016_flowers/images/image_06091.jpg
#   inflating: content/cvpr2016_flowers/images/image_06796.jpg
#   inflating: content/cvpr2016_flowers/images/image_01623.jpg
#   inflating: content/cvpr2016_flowers/images/image_02078.jpg
#   inflating: content/cvpr2016_flowers/images/image_02381.jpg
#   inflating: content/cvpr2016_flowers/images/image_03903.jpg
#   inflating: content/cvpr2016_flowers/images/image_04235.jpg
#   inflating: content/cvpr2016_flowers/images/image_02219.jpg
#   inflating: content/cvpr2016_flowers/images/image_00817.jpg
#   inflating: content/cvpr2016_flowers/images/image_07413.jpg
#   inflating: content/cvpr2016_flowers/images/image_02575.jpg
#   inflating: content/cvpr2016_flowers/images/image_05468.jpg
#   inflating: content/cvpr2016_flowers/images/image_01141.jpg
#   inflating: content/cvpr2016_flowers/images/image_07724.jpg
#   inflating: content/cvpr2016_flowers/images/image_04115.jpg
#   inflating: content/cvpr2016_flowers/images/image_05500.jpg
#   inflating: content/cvpr2016_flowers/images/image_04067.jpg
#   inflating: content/cvpr2016_flowers/images/image_04501.jpg
#   inflating: content/cvpr2016_flowers/images/image_00165.jpg
#   inflating: content/cvpr2016_flowers/images/image_07774.jpg
#   inflating: content/cvpr2016_flowers/images/image_06343.jpg
#   inflating: content/cvpr2016_flowers/images/image_03727.jpg
#   inflating: content/cvpr2016_flowers/images/image_07188.jpg
#   inflating: content/cvpr2016_flowers/images/image_06531.jpg
#   inflating: content/cvpr2016_flowers/images/image_05658.jpg
#   inflating: content/cvpr2016_flowers/images/image_03892.jpg
#   inflating: content/cvpr2016_flowers/images/image_03670.jpg
#   inflating: content/cvpr2016_flowers/images/image_03557.jpg
#   inflating: content/cvpr2016_flowers/images/image_02889.jpg
#   inflating: content/cvpr2016_flowers/images/image_07799.jpg
#   inflating: content/cvpr2016_flowers/images/image_07508.jpg
#   inflating: content/cvpr2016_flowers/images/image_03088.jpg
#   inflating: content/cvpr2016_flowers/images/image_01985.jpg
#   inflating: content/cvpr2016_flowers/images/image_05585.jpg
#   inflating: content/cvpr2016_flowers/images/image_00049.jpg
#   inflating: content/cvpr2016_flowers/images/image_01909.jpg
#   inflating: content/cvpr2016_flowers/images/image_00044.jpg
#   inflating: content/cvpr2016_flowers/images/image_04227.jpg
#   inflating: content/cvpr2016_flowers/images/image_02064.jpg
#   inflating: content/cvpr2016_flowers/images/image_05787.jpg
#   inflating: content/cvpr2016_flowers/images/image_05056.jpg
#   inflating: content/cvpr2016_flowers/images/image_04145.jpg
#   inflating: content/cvpr2016_flowers/images/image_01508.jpg
#   inflating: content/cvpr2016_flowers/images/image_01391.jpg
#   inflating: content/cvpr2016_flowers/images/image_06830.jpg
#   inflating: content/cvpr2016_flowers/images/image_07136.jpg
#   inflating: content/cvpr2016_flowers/images/image_06180.jpg
#   inflating: content/cvpr2016_flowers/images/image_01584.jpg
#   inflating: content/cvpr2016_flowers/images/image_01563.jpg
#   inflating: content/cvpr2016_flowers/images/image_03070.jpg
#   inflating: content/cvpr2016_flowers/images/image_04015.jpg
#   inflating: content/cvpr2016_flowers/images/image_01965.jpg
#   inflating: content/cvpr2016_flowers/images/image_01915.jpg
#   inflating: content/cvpr2016_flowers/images/image_03888.jpg
#   inflating: content/cvpr2016_flowers/images/image_01002.jpg
#   inflating: content/cvpr2016_flowers/images/image_01467.jpg
#   inflating: content/cvpr2016_flowers/images/image_02498.jpg
#   inflating: content/cvpr2016_flowers/images/image_01856.jpg
#   inflating: content/cvpr2016_flowers/images/image_06562.jpg
#   inflating: content/cvpr2016_flowers/images/image_03359.jpg
#   inflating: content/cvpr2016_flowers/images/image_05902.jpg
#   inflating: content/cvpr2016_flowers/images/image_02003.jpg
#   inflating: content/cvpr2016_flowers/images/image_06692.jpg
#   inflating: content/cvpr2016_flowers/images/image_06062.jpg
#   inflating: content/cvpr2016_flowers/images/image_04448.jpg
#   inflating: content/cvpr2016_flowers/images/image_02251.jpg
#   inflating: content/cvpr2016_flowers/images/image_07867.jpg
#   inflating: content/cvpr2016_flowers/images/image_08081.jpg
#   inflating: content/cvpr2016_flowers/images/image_07156.jpg
#   inflating: content/cvpr2016_flowers/images/image_01259.jpg
#   inflating: content/cvpr2016_flowers/images/image_02359.jpg
#   inflating: content/cvpr2016_flowers/images/image_03335.jpg
#   inflating: content/cvpr2016_flowers/images/image_03801.jpg
#   inflating: content/cvpr2016_flowers/images/image_08183.jpg
#   inflating: content/cvpr2016_flowers/images/image_00396.jpg
#   inflating: content/cvpr2016_flowers/images/image_06089.jpg
#   inflating: content/cvpr2016_flowers/images/image_04743.jpg
#   inflating: content/cvpr2016_flowers/images/image_01784.jpg
#   inflating: content/cvpr2016_flowers/images/image_03923.jpg
#   inflating: content/cvpr2016_flowers/images/image_03508.jpg
#   inflating: content/cvpr2016_flowers/images/image_07410.jpg
#   inflating: content/cvpr2016_flowers/images/image_04062.jpg
#   inflating: content/cvpr2016_flowers/images/image_08091.jpg
#   inflating: content/cvpr2016_flowers/images/image_07829.jpg
#   inflating: content/cvpr2016_flowers/images/image_06614.jpg
#   inflating: content/cvpr2016_flowers/images/image_02228.jpg
#   inflating: content/cvpr2016_flowers/images/image_00870.jpg
#   inflating: content/cvpr2016_flowers/images/image_02612.jpg
#   inflating: content/cvpr2016_flowers/images/image_03663.jpg
#   inflating: content/cvpr2016_flowers/images/image_03934.jpg
#   inflating: content/cvpr2016_flowers/images/image_01055.jpg
#   inflating: content/cvpr2016_flowers/images/image_01854.jpg
#   inflating: content/cvpr2016_flowers/images/image_04953.jpg
#   inflating: content/cvpr2016_flowers/images/image_03668.jpg
#   inflating: content/cvpr2016_flowers/images/image_03289.jpg
#   inflating: content/cvpr2016_flowers/images/image_00029.jpg
#   inflating: content/cvpr2016_flowers/images/image_08017.jpg
#   inflating: content/cvpr2016_flowers/images/image_05180.jpg
#   inflating: content/cvpr2016_flowers/images/image_07362.jpg
#   inflating: content/cvpr2016_flowers/images/image_02517.jpg
#   inflating: content/cvpr2016_flowers/images/image_06099.jpg
#   inflating: content/cvpr2016_flowers/images/image_03251.jpg
#   inflating: content/cvpr2016_flowers/images/image_04627.jpg
#   inflating: content/cvpr2016_flowers/images/image_06356.jpg
#   inflating: content/cvpr2016_flowers/images/image_00583.jpg
#   inflating: content/cvpr2016_flowers/images/image_02943.jpg
#   inflating: content/cvpr2016_flowers/images/image_06301.jpg
#   inflating: content/cvpr2016_flowers/images/image_07885.jpg
#   inflating: content/cvpr2016_flowers/images/image_03387.jpg
#   inflating: content/cvpr2016_flowers/images/image_03597.jpg
#   inflating: content/cvpr2016_flowers/images/image_07848.jpg
#   inflating: content/cvpr2016_flowers/images/image_04916.jpg
#   inflating: content/cvpr2016_flowers/images/image_00394.jpg
#   inflating: content/cvpr2016_flowers/images/image_03487.jpg
#   inflating: content/cvpr2016_flowers/images/image_07797.jpg
#   inflating: content/cvpr2016_flowers/images/image_04242.jpg
#   inflating: content/cvpr2016_flowers/images/image_08028.jpg
#   inflating: content/cvpr2016_flowers/images/image_03049.jpg
#   inflating: content/cvpr2016_flowers/images/image_01192.jpg
#   inflating: content/cvpr2016_flowers/images/image_00255.jpg
#   inflating: content/cvpr2016_flowers/images/image_04092.jpg
#   inflating: content/cvpr2016_flowers/images/image_03485.jpg
#   inflating: content/cvpr2016_flowers/images/image_01365.jpg
#   inflating: content/cvpr2016_flowers/images/image_03650.jpg
#   inflating: content/cvpr2016_flowers/images/image_03782.jpg
#   inflating: content/cvpr2016_flowers/images/image_02278.jpg
#   inflating: content/cvpr2016_flowers/images/image_04218.jpg
#   inflating: content/cvpr2016_flowers/images/image_00912.jpg
#   inflating: content/cvpr2016_flowers/images/image_05632.jpg
#   inflating: content/cvpr2016_flowers/images/image_00535.jpg
#   inflating: content/cvpr2016_flowers/images/image_02264.jpg
#   inflating: content/cvpr2016_flowers/images/image_04341.jpg
#   inflating: content/cvpr2016_flowers/images/image_04999.jpg
#   inflating: content/cvpr2016_flowers/images/image_00206.jpg
#   inflating: content/cvpr2016_flowers/images/image_01978.jpg
#   inflating: content/cvpr2016_flowers/images/image_03817.jpg
#   inflating: content/cvpr2016_flowers/images/image_00205.jpg
#   inflating: content/cvpr2016_flowers/images/image_02266.jpg
#   inflating: content/cvpr2016_flowers/images/image_08023.jpg
#   inflating: content/cvpr2016_flowers/images/image_06098.jpg
#   inflating: content/cvpr2016_flowers/images/image_04793.jpg
#   inflating: content/cvpr2016_flowers/images/image_03579.jpg
#   inflating: content/cvpr2016_flowers/images/image_03999.jpg
#   inflating: content/cvpr2016_flowers/images/image_02338.jpg
#   inflating: content/cvpr2016_flowers/images/image_02205.jpg
#   inflating: content/cvpr2016_flowers/images/image_04371.jpg
#   inflating: content/cvpr2016_flowers/images/image_00063.jpg
#   inflating: content/cvpr2016_flowers/images/image_02396.jpg
#   inflating: content/cvpr2016_flowers/images/image_07628.jpg
#   inflating: content/cvpr2016_flowers/images/image_02406.jpg
#   inflating: content/cvpr2016_flowers/images/image_03976.jpg
#   inflating: content/cvpr2016_flowers/images/image_05477.jpg
#   inflating: content/cvpr2016_flowers/images/image_01590.jpg
#   inflating: content/cvpr2016_flowers/images/image_08044.jpg
#   inflating: content/cvpr2016_flowers/images/image_05298.jpg
#   inflating: content/cvpr2016_flowers/images/image_05454.jpg
#   inflating: content/cvpr2016_flowers/images/image_00182.jpg
#   inflating: content/cvpr2016_flowers/images/image_02199.jpg
#   inflating: content/cvpr2016_flowers/images/image_05259.jpg
#   inflating: content/cvpr2016_flowers/images/image_07572.jpg
#   inflating: content/cvpr2016_flowers/images/image_06093.jpg
#   inflating: content/cvpr2016_flowers/images/image_06073.jpg
#   inflating: content/cvpr2016_flowers/images/image_01083.jpg
#   inflating: content/cvpr2016_flowers/images/image_08000.jpg
#   inflating: content/cvpr2016_flowers/images/image_06983.jpg
#   inflating: content/cvpr2016_flowers/images/image_00986.jpg
#   inflating: content/cvpr2016_flowers/images/image_02593.jpg
#   inflating: content/cvpr2016_flowers/images/image_07833.jpg
#   inflating: content/cvpr2016_flowers/images/image_01056.jpg
#   inflating: content/cvpr2016_flowers/images/image_04276.jpg
#   inflating: content/cvpr2016_flowers/images/image_05898.jpg
#   inflating: content/cvpr2016_flowers/images/image_01031.jpg
#   inflating: content/cvpr2016_flowers/images/image_03436.jpg
#   inflating: content/cvpr2016_flowers/images/image_07283.jpg
#   inflating: content/cvpr2016_flowers/images/image_05335.jpg
#   inflating: content/cvpr2016_flowers/images/image_00333.jpg
#   inflating: content/cvpr2016_flowers/images/image_01076.jpg
#   inflating: content/cvpr2016_flowers/images/image_02562.jpg
#   inflating: content/cvpr2016_flowers/images/image_01519.jpg
#   inflating: content/cvpr2016_flowers/images/image_01995.jpg
#   inflating: content/cvpr2016_flowers/images/image_06003.jpg
#   inflating: content/cvpr2016_flowers/images/image_07691.jpg
#   inflating: content/cvpr2016_flowers/images/image_02298.jpg
#   inflating: content/cvpr2016_flowers/images/image_07687.jpg
#   inflating: content/cvpr2016_flowers/images/image_06030.jpg
#   inflating: content/cvpr2016_flowers/images/image_06563.jpg
#   inflating: content/cvpr2016_flowers/images/image_05728.jpg
#   inflating: content/cvpr2016_flowers/images/image_02578.jpg
#   inflating: content/cvpr2016_flowers/images/image_04238.jpg
#   inflating: content/cvpr2016_flowers/images/image_04990.jpg
#   inflating: content/cvpr2016_flowers/images/image_04601.jpg
#   inflating: content/cvpr2016_flowers/images/image_02127.jpg
#   inflating: content/cvpr2016_flowers/images/image_04606.jpg
#   inflating: content/cvpr2016_flowers/images/image_06655.jpg
#   inflating: content/cvpr2016_flowers/images/image_01546.jpg
#   inflating: content/cvpr2016_flowers/images/image_07198.jpg
#   inflating: content/cvpr2016_flowers/images/image_06109.jpg
#   inflating: content/cvpr2016_flowers/images/image_06943.jpg
#   inflating: content/cvpr2016_flowers/images/image_05339.jpg
#   inflating: content/cvpr2016_flowers/images/image_02854.jpg
#   inflating: content/cvpr2016_flowers/images/image_07584.jpg
#   inflating: content/cvpr2016_flowers/images/image_05584.jpg
#   inflating: content/cvpr2016_flowers/images/image_02728.jpg
#   inflating: content/cvpr2016_flowers/images/image_05178.jpg
#   inflating: content/cvpr2016_flowers/images/image_00383.jpg
#   inflating: content/cvpr2016_flowers/images/image_06199.jpg
#   inflating: content/cvpr2016_flowers/images/image_02288.jpg
#   inflating: content/cvpr2016_flowers/images/image_07800.jpg
#   inflating: content/cvpr2016_flowers/images/image_02142.jpg
#   inflating: content/cvpr2016_flowers/images/image_00865.jpg
#   inflating: content/cvpr2016_flowers/images/image_04003.jpg
#   inflating: content/cvpr2016_flowers/images/image_02238.jpg
#   inflating: content/cvpr2016_flowers/images/image_00746.jpg
#   inflating: content/cvpr2016_flowers/images/image_01335.jpg
#   inflating: content/cvpr2016_flowers/images/image_03732.jpg
#   inflating: content/cvpr2016_flowers/images/image_07130.jpg
#   inflating: content/cvpr2016_flowers/images/image_03819.jpg
#   inflating: content/cvpr2016_flowers/images/image_05986.jpg
#   inflating: content/cvpr2016_flowers/images/image_03602.jpg
#   inflating: content/cvpr2016_flowers/images/image_04733.jpg
#   inflating: content/cvpr2016_flowers/images/image_02325.jpg
#   inflating: content/cvpr2016_flowers/images/image_02610.jpg
#   inflating: content/cvpr2016_flowers/images/image_05288.jpg
#   inflating: content/cvpr2016_flowers/images/image_01898.jpg
#   inflating: content/cvpr2016_flowers/images/image_02628.jpg
#   inflating: content/cvpr2016_flowers/images/image_04783.jpg
#   inflating: content/cvpr2016_flowers/images/image_05399.jpg
#   inflating: content/cvpr2016_flowers/images/image_03060.jpg
#   inflating: content/cvpr2016_flowers/images/image_03366.jpg
#   inflating: content/cvpr2016_flowers/images/image_04974.jpg
#   inflating: content/cvpr2016_flowers/images/image_02311.jpg
#   inflating: content/cvpr2016_flowers/images/image_07857.jpg
#   inflating: content/cvpr2016_flowers/images/image_06471.jpg
#   inflating: content/cvpr2016_flowers/images/image_05701.jpg
#   inflating: content/cvpr2016_flowers/images/image_03431.jpg
#   inflating: content/cvpr2016_flowers/images/image_01114.jpg
#   inflating: content/cvpr2016_flowers/images/image_07385.jpg
#   inflating: content/cvpr2016_flowers/images/image_05013.jpg
#   inflating: content/cvpr2016_flowers/images/image_01773.jpg
#   inflating: content/cvpr2016_flowers/images/image_00909.jpg
#   inflating: content/cvpr2016_flowers/images/image_04070.jpg
#   inflating: content/cvpr2016_flowers/images/image_02108.jpg
#   inflating: content/cvpr2016_flowers/images/image_07503.jpg
#   inflating: content/cvpr2016_flowers/images/image_02856.jpg
#   inflating: content/cvpr2016_flowers/images/image_01444.jpg
#   inflating: content/cvpr2016_flowers/images/image_07023.jpg
#   inflating: content/cvpr2016_flowers/images/image_05019.jpg
#   inflating: content/cvpr2016_flowers/images/image_02648.jpg
#   inflating: content/cvpr2016_flowers/images/image_04605.jpg
#   inflating: content/cvpr2016_flowers/images/image_03992.jpg
#   inflating: content/cvpr2016_flowers/images/image_03662.jpg
#   inflating: content/cvpr2016_flowers/images/image_02971.jpg
#   inflating: content/cvpr2016_flowers/images/image_04643.jpg
#   inflating: content/cvpr2016_flowers/images/image_07862.jpg
#   inflating: content/cvpr2016_flowers/images/image_07411.jpg
#   inflating: content/cvpr2016_flowers/images/image_01796.jpg
#   inflating: content/cvpr2016_flowers/images/image_05115.jpg
#   inflating: content/cvpr2016_flowers/images/image_00653.jpg
#   inflating: content/cvpr2016_flowers/images/image_02555.jpg
#   inflating: content/cvpr2016_flowers/images/image_07507.jpg
#   inflating: content/cvpr2016_flowers/images/image_05792.jpg
#   inflating: content/cvpr2016_flowers/images/image_02590.jpg
#   inflating: content/cvpr2016_flowers/images/image_03176.jpg
#   inflating: content/cvpr2016_flowers/images/image_01465.jpg
#   inflating: content/cvpr2016_flowers/images/image_00726.jpg
#   inflating: content/cvpr2016_flowers/images/image_03902.jpg
#   inflating: content/cvpr2016_flowers/images/image_04177.jpg
#   inflating: content/cvpr2016_flowers/images/image_01576.jpg
#   inflating: content/cvpr2016_flowers/images/image_07374.jpg
#   inflating: content/cvpr2016_flowers/images/image_02086.jpg
#   inflating: content/cvpr2016_flowers/images/image_04834.jpg
#   inflating: content/cvpr2016_flowers/images/image_06119.jpg
#   inflating: content/cvpr2016_flowers/images/image_01238.jpg
#   inflating: content/cvpr2016_flowers/images/image_00961.jpg
#   inflating: content/cvpr2016_flowers/images/image_01323.jpg
#   inflating: content/cvpr2016_flowers/images/image_03515.jpg
#   inflating: content/cvpr2016_flowers/images/image_04739.jpg
#   inflating: content/cvpr2016_flowers/images/image_00539.jpg
#   inflating: content/cvpr2016_flowers/images/image_02581.jpg
#   inflating: content/cvpr2016_flowers/images/image_04089.jpg
#   inflating: content/cvpr2016_flowers/images/image_01158.jpg
#   inflating: content/cvpr2016_flowers/images/image_07971.jpg
#   inflating: content/cvpr2016_flowers/images/image_04250.jpg
#   inflating: content/cvpr2016_flowers/images/image_04297.jpg
#   inflating: content/cvpr2016_flowers/images/image_04300.jpg
#   inflating: content/cvpr2016_flowers/images/image_07975.jpg
#   inflating: content/cvpr2016_flowers/images/image_04928.jpg
#   inflating: content/cvpr2016_flowers/images/image_03344.jpg
#   inflating: content/cvpr2016_flowers/images/image_04771.jpg
#   inflating: content/cvpr2016_flowers/images/image_05522.jpg
#   inflating: content/cvpr2016_flowers/images/image_02560.jpg
#   inflating: content/cvpr2016_flowers/images/image_00278.jpg
#   inflating: content/cvpr2016_flowers/images/image_01681.jpg
#   inflating: content/cvpr2016_flowers/images/image_05313.jpg
#   inflating: content/cvpr2016_flowers/images/image_06804.jpg
#   inflating: content/cvpr2016_flowers/images/image_03368.jpg
#   inflating: content/cvpr2016_flowers/images/image_01350.jpg
#   inflating: content/cvpr2016_flowers/images/image_07140.jpg
#   inflating: content/cvpr2016_flowers/images/image_04669.jpg
#   inflating: content/cvpr2016_flowers/images/image_02275.jpg
#   inflating: content/cvpr2016_flowers/images/image_02441.jpg
#   inflating: content/cvpr2016_flowers/images/image_07195.jpg
#   inflating: content/cvpr2016_flowers/images/image_06112.jpg
#   inflating: content/cvpr2016_flowers/images/image_05310.jpg
#   inflating: content/cvpr2016_flowers/images/image_05091.jpg
#   inflating: content/cvpr2016_flowers/images/image_06479.jpg
#   inflating: content/cvpr2016_flowers/images/image_00493.jpg
#   inflating: content/cvpr2016_flowers/images/image_02328.jpg
#   inflating: content/cvpr2016_flowers/images/image_06111.jpg
#   inflating: content/cvpr2016_flowers/images/image_01119.jpg
#   inflating: content/cvpr2016_flowers/images/image_04750.jpg
#   inflating: content/cvpr2016_flowers/images/image_02837.jpg
#   inflating: content/cvpr2016_flowers/images/image_02730.jpg
#   inflating: content/cvpr2016_flowers/images/image_07317.jpg
#   inflating: content/cvpr2016_flowers/images/image_04043.jpg
#   inflating: content/cvpr2016_flowers/images/image_06769.jpg
#   inflating: content/cvpr2016_flowers/images/image_01063.jpg
#   inflating: content/cvpr2016_flowers/images/image_03270.jpg
#   inflating: content/cvpr2016_flowers/images/image_04981.jpg
#   inflating: content/cvpr2016_flowers/images/image_07363.jpg
#   inflating: content/cvpr2016_flowers/images/image_03168.jpg
#   inflating: content/cvpr2016_flowers/images/image_02402.jpg
#   inflating: content/cvpr2016_flowers/images/image_04608.jpg
#   inflating: content/cvpr2016_flowers/images/image_01588.jpg
#   inflating: content/cvpr2016_flowers/images/image_05131.jpg
#   inflating: content/cvpr2016_flowers/images/image_01517.jpg
#   inflating: content/cvpr2016_flowers/images/image_03076.jpg
#   inflating: content/cvpr2016_flowers/images/image_07841.jpg
#   inflating: content/cvpr2016_flowers/images/image_01727.jpg
#   inflating: content/cvpr2016_flowers/images/image_01460.jpg
#   inflating: content/cvpr2016_flowers/images/image_03648.jpg
#   inflating: content/cvpr2016_flowers/images/image_01587.jpg
#   inflating: content/cvpr2016_flowers/images/image_03871.jpg
#   inflating: content/cvpr2016_flowers/images/image_02644.jpg
#   inflating: content/cvpr2016_flowers/images/image_01298.jpg
#   inflating: content/cvpr2016_flowers/images/image_01560.jpg
#   inflating: content/cvpr2016_flowers/images/image_01169.jpg
#   inflating: content/cvpr2016_flowers/images/image_01115.jpg
#   inflating: content/cvpr2016_flowers/images/image_01025.jpg
#   inflating: content/cvpr2016_flowers/images/image_03859.jpg
#   inflating: content/cvpr2016_flowers/images/image_04060.jpg
#   inflating: content/cvpr2016_flowers/images/image_01072.jpg
#   inflating: content/cvpr2016_flowers/images/image_01442.jpg
#   inflating: content/cvpr2016_flowers/images/image_07970.jpg
#   inflating: content/cvpr2016_flowers/images/image_01617.jpg
#   inflating: content/cvpr2016_flowers/images/image_01653.jpg
#   inflating: content/cvpr2016_flowers/images/image_05429.jpg
#   inflating: content/cvpr2016_flowers/images/image_06573.jpg
#   inflating: content/cvpr2016_flowers/images/image_04467.jpg
#   inflating: content/cvpr2016_flowers/images/image_00519.jpg
#   inflating: content/cvpr2016_flowers/images/image_04147.jpg
#   inflating: content/cvpr2016_flowers/images/image_01503.jpg
#   inflating: content/cvpr2016_flowers/images/image_01244.jpg
#   inflating: content/cvpr2016_flowers/images/image_04897.jpg
#   inflating: content/cvpr2016_flowers/images/image_02748.jpg
#   inflating: content/cvpr2016_flowers/images/image_02921.jpg
#   inflating: content/cvpr2016_flowers/images/image_04785.jpg
#   inflating: content/cvpr2016_flowers/images/image_02833.jpg
#   inflating: content/cvpr2016_flowers/images/image_01600.jpg
#   inflating: content/cvpr2016_flowers/images/image_06153.jpg
#   inflating: content/cvpr2016_flowers/images/image_02930.jpg
#   inflating: content/cvpr2016_flowers/images/image_06170.jpg
#   inflating: content/cvpr2016_flowers/images/image_02383.jpg
#   inflating: content/cvpr2016_flowers/images/image_02926.jpg
#   inflating: content/cvpr2016_flowers/images/image_05367.jpg
#   inflating: content/cvpr2016_flowers/images/image_03194.jpg
#   inflating: content/cvpr2016_flowers/images/image_05058.jpg
#   inflating: content/cvpr2016_flowers/images/image_02297.jpg
#   inflating: content/cvpr2016_flowers/images/image_05234.jpg
#   inflating: content/cvpr2016_flowers/images/image_03101.jpg
#   inflating: content/cvpr2016_flowers/images/image_07534.jpg
#   inflating: content/cvpr2016_flowers/images/image_02408.jpg
#   inflating: content/cvpr2016_flowers/images/image_01293.jpg
#   inflating: content/cvpr2016_flowers/images/image_02379.jpg
#   inflating: content/cvpr2016_flowers/images/image_05320.jpg
#   inflating: content/cvpr2016_flowers/images/image_06074.jpg
#   inflating: content/cvpr2016_flowers/images/image_06669.jpg
#   inflating: content/cvpr2016_flowers/images/image_03589.jpg
#   inflating: content/cvpr2016_flowers/images/image_03327.jpg
#   inflating: content/cvpr2016_flowers/images/image_04233.jpg
#   inflating: content/cvpr2016_flowers/images/image_07269.jpg
#   inflating: content/cvpr2016_flowers/images/image_00734.jpg
#   inflating: content/cvpr2016_flowers/images/image_06607.jpg
#   inflating: content/cvpr2016_flowers/images/image_05153.jpg
#   inflating: content/cvpr2016_flowers/images/image_02021.jpg
#   inflating: content/cvpr2016_flowers/images/image_07763.jpg
#   inflating: content/cvpr2016_flowers/images/image_05819.jpg
#   inflating: content/cvpr2016_flowers/images/image_04413.jpg
#   inflating: content/cvpr2016_flowers/images/image_03510.jpg
#   inflating: content/cvpr2016_flowers/images/image_05372.jpg
#   inflating: content/cvpr2016_flowers/images/image_04460.jpg
#   inflating: content/cvpr2016_flowers/images/image_07124.jpg
#   inflating: content/cvpr2016_flowers/images/image_04073.jpg
#   inflating: content/cvpr2016_flowers/images/image_06532.jpg
#   inflating: content/cvpr2016_flowers/images/image_04557.jpg
#   inflating: content/cvpr2016_flowers/images/image_05001.jpg
#   inflating: content/cvpr2016_flowers/images/image_02721.jpg
#   inflating: content/cvpr2016_flowers/images/image_01609.jpg
#   inflating: content/cvpr2016_flowers/images/image_02696.jpg
#   inflating: content/cvpr2016_flowers/images/image_00296.jpg
#   inflating: content/cvpr2016_flowers/images/image_01832.jpg
#   inflating: content/cvpr2016_flowers/images/image_06072.jpg
#   inflating: content/cvpr2016_flowers/images/image_01930.jpg
#   inflating: content/cvpr2016_flowers/images/image_07244.jpg
#   inflating: content/cvpr2016_flowers/images/image_03993.jpg
#   inflating: content/cvpr2016_flowers/images/image_04110.jpg
#   inflating: content/cvpr2016_flowers/images/image_02916.jpg
#   inflating: content/cvpr2016_flowers/images/image_03463.jpg
#   inflating: content/cvpr2016_flowers/images/image_07230.jpg
#   inflating: content/cvpr2016_flowers/images/image_06948.jpg
#   inflating: content/cvpr2016_flowers/images/image_01810.jpg
#   inflating: content/cvpr2016_flowers/images/image_04337.jpg
#   inflating: content/cvpr2016_flowers/images/image_03373.jpg
#   inflating: content/cvpr2016_flowers/images/image_03637.jpg
#   inflating: content/cvpr2016_flowers/images/image_05398.jpg
#   inflating: content/cvpr2016_flowers/images/image_02832.jpg
#   inflating: content/cvpr2016_flowers/images/image_02936.jpg
#   inflating: content/cvpr2016_flowers/images/image_06861.jpg
#   inflating: content/cvpr2016_flowers/images/image_07261.jpg
#   inflating: content/cvpr2016_flowers/images/image_00346.jpg
#   inflating: content/cvpr2016_flowers/images/image_05764.jpg
#   inflating: content/cvpr2016_flowers/images/image_02599.jpg
#   inflating: content/cvpr2016_flowers/images/image_04428.jpg
#   inflating: content/cvpr2016_flowers/images/image_00668.jpg
#   inflating: content/cvpr2016_flowers/images/image_04922.jpg
#   inflating: content/cvpr2016_flowers/images/image_07067.jpg
#   inflating: content/cvpr2016_flowers/images/image_07150.jpg
#   inflating: content/cvpr2016_flowers/images/image_02938.jpg
#   inflating: content/cvpr2016_flowers/images/image_03293.jpg
#   inflating: content/cvpr2016_flowers/images/image_06364.jpg
#   inflating: content/cvpr2016_flowers/images/image_06322.jpg
#   inflating: content/cvpr2016_flowers/images/image_00866.jpg
#   inflating: content/cvpr2016_flowers/images/image_06961.jpg
#   inflating: content/cvpr2016_flowers/images/image_06891.jpg
#   inflating: content/cvpr2016_flowers/images/image_04593.jpg
#   inflating: content/cvpr2016_flowers/images/image_02225.jpg
#   inflating: content/cvpr2016_flowers/images/image_00452.jpg
#   inflating: content/cvpr2016_flowers/images/image_06743.jpg
#   inflating: content/cvpr2016_flowers/images/image_02425.jpg
#   inflating: content/cvpr2016_flowers/images/image_07331.jpg
#   inflating: content/cvpr2016_flowers/images/image_01089.jpg
#   inflating: content/cvpr2016_flowers/images/image_02950.jpg
#   inflating: content/cvpr2016_flowers/images/image_01458.jpg
#   inflating: content/cvpr2016_flowers/images/image_02177.jpg
#   inflating: content/cvpr2016_flowers/images/image_02326.jpg
#   inflating: content/cvpr2016_flowers/images/image_01187.jpg
#   inflating: content/cvpr2016_flowers/images/image_05885.jpg
#   inflating: content/cvpr2016_flowers/images/image_04701.jpg
#   inflating: content/cvpr2016_flowers/images/image_07566.jpg
#   inflating: content/cvpr2016_flowers/images/image_03519.jpg
#   inflating: content/cvpr2016_flowers/images/image_07624.jpg
#   inflating: content/cvpr2016_flowers/images/image_03046.jpg
#   inflating: content/cvpr2016_flowers/images/image_05889.jpg
#   inflating: content/cvpr2016_flowers/images/image_05929.jpg
#   inflating: content/cvpr2016_flowers/images/image_03991.jpg
#   inflating: content/cvpr2016_flowers/images/image_01113.jpg
#   inflating: content/cvpr2016_flowers/images/image_04583.jpg
#   inflating: content/cvpr2016_flowers/images/image_05198.jpg
#   inflating: content/cvpr2016_flowers/images/image_04476.jpg
#   inflating: content/cvpr2016_flowers/images/image_00992.jpg
#   inflating: content/cvpr2016_flowers/images/image_06789.jpg
#   inflating: content/cvpr2016_flowers/images/image_05470.jpg
#   inflating: content/cvpr2016_flowers/images/image_07077.jpg
#   inflating: content/cvpr2016_flowers/images/image_04209.jpg
#   inflating: content/cvpr2016_flowers/images/image_03671.jpg
#   inflating: content/cvpr2016_flowers/images/image_00849.jpg
#   inflating: content/cvpr2016_flowers/images/image_05370.jpg
#   inflating: content/cvpr2016_flowers/images/image_01362.jpg
#   inflating: content/cvpr2016_flowers/images/image_07394.jpg
#   inflating: content/cvpr2016_flowers/images/image_08150.jpg
#   inflating: content/cvpr2016_flowers/images/image_00842.jpg
#   inflating: content/cvpr2016_flowers/images/image_07373.jpg
#   inflating: content/cvpr2016_flowers/images/image_01395.jpg
#   inflating: content/cvpr2016_flowers/images/image_01993.jpg
#   inflating: content/cvpr2016_flowers/images/image_03316.jpg
#   inflating: content/cvpr2016_flowers/images/image_01512.jpg
#   inflating: content/cvpr2016_flowers/images/image_00991.jpg
#   inflating: content/cvpr2016_flowers/images/image_05808.jpg
#   inflating: content/cvpr2016_flowers/images/image_07518.jpg
#   inflating: content/cvpr2016_flowers/images/image_05930.jpg
#   inflating: content/cvpr2016_flowers/images/image_00018.jpg
#   inflating: content/cvpr2016_flowers/images/image_06353.jpg
#   inflating: content/cvpr2016_flowers/images/image_03765.jpg
#   inflating: content/cvpr2016_flowers/images/image_05296.jpg
#   inflating: content/cvpr2016_flowers/images/image_01127.jpg
#   inflating: content/cvpr2016_flowers/images/image_01764.jpg
#   inflating: content/cvpr2016_flowers/images/image_04321.jpg
#   inflating: content/cvpr2016_flowers/images/image_06137.jpg
#   inflating: content/cvpr2016_flowers/images/image_05072.jpg
#   inflating: content/cvpr2016_flowers/images/image_00916.jpg
#   inflating: content/cvpr2016_flowers/images/image_03095.jpg
#   inflating: content/cvpr2016_flowers/images/image_05119.jpg
#   inflating: content/cvpr2016_flowers/images/image_04098.jpg
#   inflating: content/cvpr2016_flowers/images/image_06715.jpg
#   inflating: content/cvpr2016_flowers/images/image_04164.jpg
#   inflating: content/cvpr2016_flowers/images/image_00062.jpg
#   inflating: content/cvpr2016_flowers/images/image_07233.jpg
#   inflating: content/cvpr2016_flowers/images/image_00136.jpg
#   inflating: content/cvpr2016_flowers/images/image_01200.jpg
#   inflating: content/cvpr2016_flowers/images/image_00629.jpg
#   inflating: content/cvpr2016_flowers/images/image_05720.jpg
#   inflating: content/cvpr2016_flowers/images/image_00830.jpg
#   inflating: content/cvpr2016_flowers/images/image_01342.jpg
#   inflating: content/cvpr2016_flowers/images/image_01221.jpg
#   inflating: content/cvpr2016_flowers/images/image_04799.jpg
#   inflating: content/cvpr2016_flowers/images/image_02105.jpg
#   inflating: content/cvpr2016_flowers/images/image_02514.jpg
#   inflating: content/cvpr2016_flowers/images/image_04243.jpg
#   inflating: content/cvpr2016_flowers/images/image_06847.jpg
#   inflating: content/cvpr2016_flowers/images/image_07761.jpg
#   inflating: content/cvpr2016_flowers/images/image_00197.jpg
#   inflating: content/cvpr2016_flowers/images/image_00269.jpg
#   inflating: content/cvpr2016_flowers/images/image_00988.jpg
#   inflating: content/cvpr2016_flowers/images/image_00087.jpg
#   inflating: content/cvpr2016_flowers/images/image_05950.jpg
#   inflating: content/cvpr2016_flowers/images/image_03921.jpg
#   inflating: content/cvpr2016_flowers/images/image_05936.jpg
#   inflating: content/cvpr2016_flowers/images/image_06623.jpg
#   inflating: content/cvpr2016_flowers/images/image_05901.jpg
#   inflating: content/cvpr2016_flowers/images/image_06812.jpg
#   inflating: content/cvpr2016_flowers/images/image_01689.jpg
#   inflating: content/cvpr2016_flowers/images/image_03469.jpg
#   inflating: content/cvpr2016_flowers/images/image_07823.jpg
#   inflating: content/cvpr2016_flowers/images/image_07384.jpg
#   inflating: content/cvpr2016_flowers/images/image_00435.jpg
#   inflating: content/cvpr2016_flowers/images/image_08087.jpg
#   inflating: content/cvpr2016_flowers/images/image_00682.jpg
#   inflating: content/cvpr2016_flowers/images/image_02714.jpg
#   inflating: content/cvpr2016_flowers/images/image_02043.jpg
#   inflating: content/cvpr2016_flowers/images/image_04857.jpg
#   inflating: content/cvpr2016_flowers/images/image_05067.jpg
#   inflating: content/cvpr2016_flowers/images/image_08040.jpg
#   inflating: content/cvpr2016_flowers/images/image_05982.jpg
#   inflating: content/cvpr2016_flowers/images/image_01612.jpg
#   inflating: content/cvpr2016_flowers/images/image_02034.jpg
#   inflating: content/cvpr2016_flowers/images/image_05054.jpg
#   inflating: content/cvpr2016_flowers/images/image_02747.jpg
#   inflating: content/cvpr2016_flowers/images/image_02087.jpg
#   inflating: content/cvpr2016_flowers/images/image_03378.jpg
#   inflating: content/cvpr2016_flowers/images/image_05332.jpg
#   inflating: content/cvpr2016_flowers/images/image_01142.jpg
#   inflating: content/cvpr2016_flowers/images/image_01311.jpg
#   inflating: content/cvpr2016_flowers/images/image_03068.jpg
#   inflating: content/cvpr2016_flowers/images/image_02632.jpg
#   inflating: content/cvpr2016_flowers/images/image_01249.jpg
#   inflating: content/cvpr2016_flowers/images/image_04736.jpg
#   inflating: content/cvpr2016_flowers/images/image_06431.jpg
#   inflating: content/cvpr2016_flowers/images/image_00050.jpg
#   inflating: content/cvpr2016_flowers/images/image_03445.jpg
#   inflating: content/cvpr2016_flowers/images/image_05465.jpg
#   inflating: content/cvpr2016_flowers/images/image_03242.jpg
#   inflating: content/cvpr2016_flowers/images/image_01907.jpg
#   inflating: content/cvpr2016_flowers/images/image_05414.jpg
#   inflating: content/cvpr2016_flowers/images/image_03827.jpg
#   inflating: content/cvpr2016_flowers/images/image_00868.jpg
#   inflating: content/cvpr2016_flowers/images/image_07545.jpg
#   inflating: content/cvpr2016_flowers/images/image_05409.jpg
#   inflating: content/cvpr2016_flowers/images/image_04404.jpg
#   inflating: content/cvpr2016_flowers/images/image_04305.jpg
#   inflating: content/cvpr2016_flowers/images/image_05113.jpg
#   inflating: content/cvpr2016_flowers/images/image_01790.jpg
#   inflating: content/cvpr2016_flowers/images/image_00838.jpg
#   inflating: content/cvpr2016_flowers/images/image_04891.jpg
#   inflating: content/cvpr2016_flowers/images/image_04890.jpg
#   inflating: content/cvpr2016_flowers/images/image_04693.jpg
#   inflating: content/cvpr2016_flowers/images/image_05892.jpg
#   inflating: content/cvpr2016_flowers/images/image_03503.jpg
#   inflating: content/cvpr2016_flowers/images/image_05216.jpg
#   inflating: content/cvpr2016_flowers/images/image_00591.jpg
#   inflating: content/cvpr2016_flowers/images/image_00464.jpg
#   inflating: content/cvpr2016_flowers/images/image_08100.jpg
#   inflating: content/cvpr2016_flowers/images/image_01608.jpg
#   inflating: content/cvpr2016_flowers/images/image_05172.jpg
#   inflating: content/cvpr2016_flowers/images/image_06141.jpg
#   inflating: content/cvpr2016_flowers/images/image_01824.jpg
#   inflating: content/cvpr2016_flowers/images/image_04394.jpg
#   inflating: content/cvpr2016_flowers/images/image_03635.jpg
#   inflating: content/cvpr2016_flowers/images/image_07236.jpg
#   inflating: content/cvpr2016_flowers/images/image_07004.jpg
#   inflating: content/cvpr2016_flowers/images/image_03639.jpg
#   inflating: content/cvpr2016_flowers/images/image_01386.jpg
#   inflating: content/cvpr2016_flowers/images/image_01329.jpg
#   inflating: content/cvpr2016_flowers/images/image_05791.jpg
#   inflating: content/cvpr2016_flowers/images/image_02520.jpg
#   inflating: content/cvpr2016_flowers/images/image_01179.jpg
#   inflating: content/cvpr2016_flowers/images/image_04167.jpg
#   inflating: content/cvpr2016_flowers/images/image_06649.jpg
#   inflating: content/cvpr2016_flowers/images/image_00518.jpg
#   inflating: content/cvpr2016_flowers/images/image_02577.jpg
#   inflating: content/cvpr2016_flowers/images/image_00178.jpg
# ...
#   inflating: content/cvpr2016_flowers/images/image_03402.jpg
#   inflating: content/cvpr2016_flowers/images/image_04453.jpg
#   inflating: content/cvpr2016_flowers/images/image_04714.jpg
#   inflating: content/cvpr2016_flowers/images/image_02863.jpg
#   inflating: content/cvpr2016_flowers/images/image_01875.jpg
#   inflating: content/cvpr2016_flowers/images/image_05661.jpg
#   inflating: content/cvpr2016_flowers/images/image_00841.jpg
#   inflating: content/cvpr2016_flowers/images/image_01109.jpg
#   inflating: content/cvpr2016_flowers/images/image_06845.jpg
#   inflating: content/cvpr2016_flowers/images/image_07184.jpg
#   inflating: content/cvpr2016_flowers/images/image_06952.jpg
#   inflating: content/cvpr2016_flowers/images/image_01052.jpg
#   inflating: content/cvpr2016_flowers/images/image_00015.jpg
#   inflating: content/cvpr2016_flowers/images/image_02320.jpg
#   inflating: content/cvpr2016_flowers/images/image_08058.jpg
#   inflating: content/cvpr2016_flowers/images/image_00093.jpg
#   inflating: content/cvpr2016_flowers/images/image_01602.jpg
#   inflating: content/cvpr2016_flowers/images/image_03705.jpg
#   inflating: content/cvpr2016_flowers/images/image_03975.jpg
#   inflating: content/cvpr2016_flowers/images/image_04426.jpg
#   inflating: content/cvpr2016_flowers/images/image_02543.jpg
#   inflating: content/cvpr2016_flowers/images/image_04576.jpg
#   inflating: content/cvpr2016_flowers/images/image_01388.jpg
#   inflating: content/cvpr2016_flowers/images/image_01364.jpg
#   inflating: content/cvpr2016_flowers/images/image_03883.jpg
#   inflating: content/cvpr2016_flowers/images/image_07144.jpg
#   inflating: content/cvpr2016_flowers/images/image_05221.jpg
#   inflating: content/cvpr2016_flowers/images/image_01106.jpg
#   inflating: content/cvpr2016_flowers/images/image_00708.jpg
#   inflating: content/cvpr2016_flowers/images/image_07292.jpg
#   inflating: content/cvpr2016_flowers/images/image_07756.jpg
#   inflating: content/cvpr2016_flowers/images/image_04154.jpg
#   inflating: content/cvpr2016_flowers/images/image_04333.jpg
#   inflating: content/cvpr2016_flowers/images/image_08003.jpg
#   inflating: content/cvpr2016_flowers/images/image_01522.jpg
#   inflating: content/cvpr2016_flowers/images/image_06169.jpg
#   inflating: content/cvpr2016_flowers/images/image_00878.jpg
#   inflating: content/cvpr2016_flowers/images/image_07953.jpg
#   inflating: content/cvpr2016_flowers/images/image_04719.jpg
#   inflating: content/cvpr2016_flowers/images/image_00469.jpg
#   inflating: content/cvpr2016_flowers/images/image_01520.jpg
#   inflating: content/cvpr2016_flowers/images/image_03585.jpg
#   inflating: content/cvpr2016_flowers/images/image_04443.jpg
#   inflating: content/cvpr2016_flowers/images/image_04707.jpg
#   inflating: content/cvpr2016_flowers/images/image_02592.jpg
#   inflating: content/cvpr2016_flowers/images/image_02399.jpg
#   inflating: content/cvpr2016_flowers/images/image_05832.jpg
#   inflating: content/cvpr2016_flowers/images/image_01250.jpg
#   inflating: content/cvpr2016_flowers/images/image_00745.jpg
#   inflating: content/cvpr2016_flowers/images/image_05163.jpg
#   inflating: content/cvpr2016_flowers/images/image_00459.jpg
#   inflating: content/cvpr2016_flowers/images/image_06974.jpg
#   inflating: content/cvpr2016_flowers/images/image_04767.jpg
#   inflating: content/cvpr2016_flowers/images/image_00974.jpg
#   inflating: content/cvpr2016_flowers/images/image_06770.jpg
#   inflating: content/cvpr2016_flowers/images/image_06863.jpg
#   inflating: content/cvpr2016_flowers/images/image_08172.jpg
#   inflating: content/cvpr2016_flowers/images/image_06835.jpg
#   inflating: content/cvpr2016_flowers/images/image_02001.jpg
#   inflating: content/cvpr2016_flowers/images/image_00803.jpg
#   inflating: content/cvpr2016_flowers/images/image_01777.jpg
#   inflating: content/cvpr2016_flowers/images/image_07579.jpg
#   inflating: content/cvpr2016_flowers/images/image_01290.jpg
#   inflating: content/cvpr2016_flowers/images/image_03351.jpg
#   inflating: content/cvpr2016_flowers/images/image_00990.jpg
#   inflating: content/cvpr2016_flowers/images/image_03584.jpg
#   inflating: content/cvpr2016_flowers/images/image_03773.jpg
#   inflating: content/cvpr2016_flowers/images/image_07109.jpg
#   inflating: content/cvpr2016_flowers/images/image_03339.jpg
#   inflating: content/cvpr2016_flowers/images/image_01789.jpg
#   inflating: content/cvpr2016_flowers/images/image_00221.jpg
#   inflating: content/cvpr2016_flowers/images/image_05622.jpg
#   inflating: content/cvpr2016_flowers/images/image_01107.jpg
#   inflating: content/cvpr2016_flowers/images/image_06187.jpg
#   inflating: content/cvpr2016_flowers/images/image_05664.jpg
#   inflating: content/cvpr2016_flowers/images/image_01067.jpg
#   inflating: content/cvpr2016_flowers/images/image_01800.jpg
#   inflating: content/cvpr2016_flowers/images/image_07753.jpg
#   inflating: content/cvpr2016_flowers/images/image_03385.jpg
#   inflating: content/cvpr2016_flowers/images/image_07218.jpg
#   inflating: content/cvpr2016_flowers/images/image_03413.jpg
#   inflating: content/cvpr2016_flowers/images/image_02966.jpg
#   inflating: content/cvpr2016_flowers/images/image_01219.jpg
#   inflating: content/cvpr2016_flowers/images/image_00083.jpg
#   inflating: content/cvpr2016_flowers/images/image_02272.jpg
#   inflating: content/cvpr2016_flowers/images/image_07040.jpg
#   inflating: content/cvpr2016_flowers/images/image_06694.jpg
#   inflating: content/cvpr2016_flowers/images/image_07617.jpg
#   inflating: content/cvpr2016_flowers/images/image_06874.jpg
#   inflating: content/cvpr2016_flowers/images/image_01120.jpg
#   inflating: content/cvpr2016_flowers/images/image_02647.jpg
#   inflating: content/cvpr2016_flowers/images/image_03065.jpg
#   inflating: content/cvpr2016_flowers/images/image_00793.jpg
#   inflating: content/cvpr2016_flowers/images/image_06714.jpg
#   inflating: content/cvpr2016_flowers/images/image_05727.jpg
#   inflating: content/cvpr2016_flowers/images/image_07704.jpg
#   inflating: content/cvpr2016_flowers/images/image_02196.jpg
#   inflating: content/cvpr2016_flowers/images/image_01571.jpg
#   inflating: content/cvpr2016_flowers/images/image_05551.jpg
#   inflating: content/cvpr2016_flowers/images/image_02217.jpg
#   inflating: content/cvpr2016_flowers/images/image_06631.jpg
#   inflating: content/cvpr2016_flowers/images/image_04468.jpg
#   inflating: content/cvpr2016_flowers/images/image_00388.jpg
#   inflating: content/cvpr2016_flowers/images/image_02146.jpg
#   inflating: content/cvpr2016_flowers/images/image_01384.jpg
#   inflating: content/cvpr2016_flowers/images/image_00861.jpg
#   inflating: content/cvpr2016_flowers/images/image_03784.jpg
#   inflating: content/cvpr2016_flowers/images/image_01324.jpg
#   inflating: content/cvpr2016_flowers/images/image_02241.jpg
#   inflating: content/cvpr2016_flowers/images/image_01820.jpg
#   inflating: content/cvpr2016_flowers/images/image_03295.jpg
#   inflating: content/cvpr2016_flowers/images/image_01528.jpg
#   inflating: content/cvpr2016_flowers/images/image_07228.jpg
#   inflating: content/cvpr2016_flowers/images/image_01413.jpg
#   inflating: content/cvpr2016_flowers/images/image_06303.jpg
#   inflating: content/cvpr2016_flowers/images/image_02824.jpg
#   inflating: content/cvpr2016_flowers/images/image_05201.jpg
#   inflating: content/cvpr2016_flowers/images/image_00731.jpg
#   inflating: content/cvpr2016_flowers/images/image_01410.jpg
#   inflating: content/cvpr2016_flowers/images/image_03449.jpg
#   inflating: content/cvpr2016_flowers/images/image_05144.jpg
#   inflating: content/cvpr2016_flowers/images/image_07675.jpg
#   inflating: content/cvpr2016_flowers/images/image_07084.jpg
#   inflating: content/cvpr2016_flowers/images/image_05709.jpg
#   inflating: content/cvpr2016_flowers/images/image_01143.jpg
#   inflating: content/cvpr2016_flowers/images/image_07745.jpg
#   inflating: content/cvpr2016_flowers/images/image_02040.jpg
#   inflating: content/cvpr2016_flowers/images/image_00443.jpg
#   inflating: content/cvpr2016_flowers/images/image_06182.jpg
#   inflating: content/cvpr2016_flowers/images/image_04036.jpg
#   inflating: content/cvpr2016_flowers/images/image_05488.jpg
#   inflating: content/cvpr2016_flowers/images/image_02677.jpg
#   inflating: content/cvpr2016_flowers/images/image_00548.jpg
#   inflating: content/cvpr2016_flowers/images/image_01726.jpg
#   inflating: content/cvpr2016_flowers/images/image_02247.jpg
#   inflating: content/cvpr2016_flowers/images/image_05683.jpg
#   inflating: content/cvpr2016_flowers/images/image_01313.jpg
#   inflating: content/cvpr2016_flowers/images/image_04272.jpg
#   inflating: content/cvpr2016_flowers/images/image_02497.jpg
#   inflating: content/cvpr2016_flowers/images/image_04155.jpg
#   inflating: content/cvpr2016_flowers/images/image_03420.jpg
#   inflating: content/cvpr2016_flowers/images/image_04195.jpg
#   inflating: content/cvpr2016_flowers/images/image_03057.jpg
#   inflating: content/cvpr2016_flowers/images/image_06962.jpg
#   inflating: content/cvpr2016_flowers/images/image_03618.jpg
#   inflating: content/cvpr2016_flowers/images/image_07555.jpg
#   inflating: content/cvpr2016_flowers/images/image_01336.jpg
#   inflating: content/cvpr2016_flowers/images/image_01583.jpg
#   inflating: content/cvpr2016_flowers/images/image_05165.jpg
#   inflating: content/cvpr2016_flowers/images/image_02460.jpg
#   inflating: content/cvpr2016_flowers/images/image_02159.jpg
#   inflating: content/cvpr2016_flowers/images/image_03878.jpg
#   inflating: content/cvpr2016_flowers/images/image_04581.jpg
#   inflating: content/cvpr2016_flowers/images/image_03001.jpg
#   inflating: content/cvpr2016_flowers/images/image_07435.jpg
#   inflating: content/cvpr2016_flowers/images/image_03467.jpg
#   inflating: content/cvpr2016_flowers/images/image_03253.jpg
#   inflating: content/cvpr2016_flowers/images/image_00835.jpg
#   inflating: content/cvpr2016_flowers/images/image_01666.jpg
#   inflating: content/cvpr2016_flowers/images/image_05384.jpg
#   inflating: content/cvpr2016_flowers/images/image_01090.jpg
#   inflating: content/cvpr2016_flowers/images/image_05544.jpg
#   inflating: content/cvpr2016_flowers/images/image_06928.jpg
#   inflating: content/cvpr2016_flowers/images/image_07049.jpg
#   inflating: content/cvpr2016_flowers/images/image_07253.jpg
#   inflating: content/cvpr2016_flowers/images/image_05620.jpg
#   inflating: content/cvpr2016_flowers/images/image_03966.jpg
#   inflating: content/cvpr2016_flowers/images/image_06779.jpg
#   inflating: content/cvpr2016_flowers/images/image_06556.jpg
#   inflating: content/cvpr2016_flowers/images/image_06875.jpg
#   inflating: content/cvpr2016_flowers/images/image_05595.jpg
#   inflating: content/cvpr2016_flowers/images/image_04457.jpg
#   inflating: content/cvpr2016_flowers/images/image_07282.jpg
#   inflating: content/cvpr2016_flowers/images/image_02113.jpg
#   inflating: content/cvpr2016_flowers/images/image_05311.jpg
#   inflating: content/cvpr2016_flowers/images/image_00994.jpg
#   inflating: content/cvpr2016_flowers/images/image_04472.jpg
#   inflating: content/cvpr2016_flowers/images/image_00365.jpg
#   inflating: content/cvpr2016_flowers/images/image_03525.jpg
#   inflating: content/cvpr2016_flowers/images/image_02002.jpg
#   inflating: content/cvpr2016_flowers/images/image_07995.jpg
#   inflating: content/cvpr2016_flowers/images/image_00561.jpg
#   inflating: content/cvpr2016_flowers/images/image_02624.jpg
#   inflating: content/cvpr2016_flowers/images/image_06885.jpg
#   inflating: content/cvpr2016_flowers/images/image_00274.jpg
#   inflating: content/cvpr2016_flowers/images/image_02204.jpg
#   inflating: content/cvpr2016_flowers/images/image_06039.jpg
#   inflating: content/cvpr2016_flowers/images/image_06165.jpg
#   inflating: content/cvpr2016_flowers/images/image_04084.jpg
#   inflating: content/cvpr2016_flowers/images/image_05229.jpg
#   inflating: content/cvpr2016_flowers/images/image_01524.jpg
#   inflating: content/cvpr2016_flowers/images/image_00570.jpg
#   inflating: content/cvpr2016_flowers/images/image_02267.jpg
#   inflating: content/cvpr2016_flowers/images/image_04216.jpg
#   inflating: content/cvpr2016_flowers/images/image_07814.jpg
#   inflating: content/cvpr2016_flowers/images/image_01397.jpg
#   inflating: content/cvpr2016_flowers/images/image_03216.jpg
#   inflating: content/cvpr2016_flowers/images/image_02563.jpg
#   inflating: content/cvpr2016_flowers/images/image_08053.jpg
#   inflating: content/cvpr2016_flowers/images/image_05417.jpg
#   inflating: content/cvpr2016_flowers/images/image_00568.jpg
#   inflating: content/cvpr2016_flowers/images/image_03666.jpg
#   inflating: content/cvpr2016_flowers/images/image_06151.jpg
#   inflating: content/cvpr2016_flowers/images/image_02387.jpg
#   inflating: content/cvpr2016_flowers/images/image_04552.jpg
#   inflating: content/cvpr2016_flowers/images/image_06385.jpg
#   inflating: content/cvpr2016_flowers/images/image_00423.jpg
#   inflating: content/cvpr2016_flowers/images/image_01380.jpg
#   inflating: content/cvpr2016_flowers/images/image_06580.jpg
#   inflating: content/cvpr2016_flowers/images/image_06954.jpg
#   inflating: content/cvpr2016_flowers/images/image_07464.jpg
#   inflating: content/cvpr2016_flowers/images/image_01309.jpg
#   inflating: content/cvpr2016_flowers/images/image_00950.jpg
#   inflating: content/cvpr2016_flowers/images/image_04171.jpg
#   inflating: content/cvpr2016_flowers/images/image_02538.jpg
#   inflating: content/cvpr2016_flowers/images/image_01034.jpg
#   inflating: content/cvpr2016_flowers/images/image_00137.jpg
#   inflating: content/cvpr2016_flowers/images/image_04549.jpg
#   inflating: content/cvpr2016_flowers/images/image_00834.jpg
#   inflating: content/cvpr2016_flowers/images/image_00892.jpg
#   inflating: content/cvpr2016_flowers/images/image_06094.jpg
#   inflating: content/cvpr2016_flowers/images/image_05426.jpg
#   inflating: content/cvpr2016_flowers/images/image_00431.jpg
#   inflating: content/cvpr2016_flowers/images/image_03869.jpg
#   inflating: content/cvpr2016_flowers/images/image_04716.jpg
#   inflating: content/cvpr2016_flowers/images/image_07563.jpg
#   inflating: content/cvpr2016_flowers/images/image_04571.jpg
#   inflating: content/cvpr2016_flowers/images/image_05205.jpg
#   inflating: content/cvpr2016_flowers/images/image_01475.jpg
#   inflating: content/cvpr2016_flowers/images/image_04629.jpg
#   inflating: content/cvpr2016_flowers/images/image_00475.jpg
#   inflating: content/cvpr2016_flowers/images/image_06584.jpg
#   inflating: content/cvpr2016_flowers/images/image_01094.jpg
#   inflating: content/cvpr2016_flowers/images/image_02680.jpg
#   inflating: content/cvpr2016_flowers/images/image_04894.jpg
#   inflating: content/cvpr2016_flowers/images/image_02417.jpg
#   inflating: content/cvpr2016_flowers/images/image_00554.jpg
#   inflating: content/cvpr2016_flowers/images/image_04562.jpg
#   inflating: content/cvpr2016_flowers/images/image_08048.jpg
#   inflating: content/cvpr2016_flowers/images/image_06396.jpg
#   inflating: content/cvpr2016_flowers/images/image_07544.jpg
#   inflating: content/cvpr2016_flowers/images/image_04753.jpg
#   inflating: content/cvpr2016_flowers/images/image_04125.jpg
#   inflating: content/cvpr2016_flowers/images/image_05777.jpg
#   inflating: content/cvpr2016_flowers/images/image_07768.jpg
#   inflating: content/cvpr2016_flowers/images/image_06554.jpg
#   inflating: content/cvpr2016_flowers/images/image_02048.jpg
#   inflating: content/cvpr2016_flowers/images/image_07889.jpg
#   inflating: content/cvpr2016_flowers/images/image_06327.jpg
#   inflating: content/cvpr2016_flowers/images/image_05835.jpg
#   inflating: content/cvpr2016_flowers/images/image_05299.jpg
#   inflating: content/cvpr2016_flowers/images/image_05900.jpg
#   inflating: content/cvpr2016_flowers/images/image_02737.jpg
#    creating: content/cvpr2016_flowers/.ipynb_checkpoints/

# %%
# load caption
import os

# mục đích: trả về dict(tên ảnh, caption)
def load_captions(caption_path, image_path):
  captions = {}
  image_files = os.listdir(image_path)
  for image_file in image_files:
    image_name = image_file.split(".")[0]
    caption_file = os.path.join(caption_path, image_name + ".txt")
    with open(caption_file, "r") as f:
      caption = f.readlines()[0].strip()
    if image_name not in captions:
      captions[image_name] = caption
  return captions

# %%
captions_path = "/content/content/cvpr2016_flowers/captions"

image_path = "/content/content/cvpr2016_flowers/images"

captions = load_captions(captions_path, image_path)
captions

# %% [markdown]
# sử dụng mô hình BERTs để biểu diễn mỗi câu mô tả thành một vector có
# kích thước 768 chiều

# %%
# !pip install sentence_transformers

# %%
import torch
import numpy as np
from sentence_transformers import SentenceTransformer

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bert_model = SentenceTransformer("all-mpnet-base-v2").to(device)

# mục đích: tạo một hàm trả về caption, embedding
def encode_captions(captions):
  encoded_captions = {}
  for image_name in captions.keys():
    caption = captions[image_name]
    encoded_captions[image_name] = {
        'embed': torch.tensor(bert_model.encode(caption)).to(device),
        'text': caption
    }
  return encoded_captions

# %%
encoded_captions = encode_captions(captions)

# %%
encoded_captions

# %%
print(encoded_captions['image_05881'])

# %%
# thực hiện processing
from PIL import Image
from torch.utils.data import Dataset

class FlowerDataset(Dataset):
  def __init__(self, img_dir, captions, transform = None):
    self.img_dir = img_dir
    self.captions = captions
    self.transform = transform
    self.img_names = list(captions.keys())

  def __len__(self):
    return len(self.img_names)

  def __getitem__(self, idx):
    img_name = self.img_names[idx]
    img_path = os.path.join(self.img_dir, img_name + '.jpg')
    img = Image.open(img_path).convert("RGB")
    if self.transform:
      img = self.transform(img)
    encoded_caption = self.captions[img_name]['embed']
    caption = self.captions[img_name]['text']
    # The return statement was below the dictionary, causing it to return None.
    # Move it above the dictionary to return the dictionary instead.
    return {
        'image': img,
        'caption': caption,
        'encoded_caption': encoded_caption
    }

# %%
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

IMG_SIZE = 128

transform = transforms.Compose(
    [
     transforms.Resize((IMG_SIZE, IMG_SIZE)),
     transforms.ToTensor(),
     transforms.Normalize([0.5],[0.5])
    ]
)

BATCH_SIZE = 64
image_path = "/content/content/cvpr2016_flowers/images"
ds = FlowerDataset(image_path, encoded_captions, transform)
load_dataset = DataLoader(ds, batch_size = BATCH_SIZE , shuffle = True)

# %% [markdown]
# ### Xây dựng model

# %%
# tạo class Generator
import torch
import torch.nn as nn
import torch.nn.functional as F

class Generator(torch.nn.Module):
  def __init__(self, noise_size, feature_size,
               num_channels, embedding_size,
               reduced_dim_size):
    super(Generator, self).__init__()
    self.reduced_dim_size = reduced_dim_size

    # tạo một biến model => mục đích giảm số chiều 768 -> 256
    self.text_encoder = nn.Sequential(
        nn.Linear(embedding_size, reduced_dim_size),
        nn.BatchNorm1d(reduced_dim_size),
        nn.LeakyReLU(negative_slope = 0.2, inplace = True),
        nn.Linear(reduced_dim_size, reduced_dim_size)
    )

    self.upsampling = nn.Sequential(
        # 100 + 256
        nn.ConvTranspose2d(noise_size + reduced_dim_size, feature_size*8, 4, 1, 0, bias = False),
        nn.BatchNorm2d(feature_size*8), # 1024
        nn.ReLU(inplace = True),

        # 1024 -> 512
        nn.ConvTranspose2d(feature_size*8, feature_size*4, 4, 2, 1, bias = False),
        nn.BatchNorm2d(feature_size*4), # 512
        nn.ReLU(inplace = True),

        # 512 -> 256
        nn.ConvTranspose2d(feature_size*4, feature_size*2, 4, 2, 1, bias = False),
        nn.BatchNorm2d(feature_size*2), # 256
        nn.ReLU(inplace = True),

        # 256 -> 128
        nn.ConvTranspose2d(feature_size*2, feature_size, 4, 2, 1, bias = False),
        nn.BatchNorm2d(feature_size), # 128
        nn.ReLU(inplace = True),

        # 128 -> 128
        nn.ConvTranspose2d(feature_size, feature_size, 4, 2, 1, bias = False),
        nn.BatchNorm2d(feature_size), # 128
        nn.ReLU(inplace = True),

        # 128 -> 3
        nn.ConvTranspose2d(128, num_channels, 4, 2, 1, bias = False),
        nn.Tanh()
    )

    # tại sao lại dùng hàm Tanh()?
    # vì ảnh được normalization với chuẩn (0.5, 0.5)

  def forward(self, noise, text_embedding):
    text_encoder = self.text_encoder(text_embedding)
    # tạo một input có shape (batch_size, 256, 1, 1)
    concat_input = torch.cat([noise, text_encoder], dim = 1).unsqueeze(2).unsqueeze(2)
    output = self.upsampling(concat_input)
    return output

# %%
# tạo một class disciminator
class Discriminator(torch.nn.Module):
  def __init__(self, num_channels, feature_size, embedding_size, reduced_dim_size):
    super(Discriminator, self).__init__()
    self.reduced_dim_size = reduced_dim_size

    self.img_encoder = nn.Sequential(
        # 3 -> 128
        nn.Conv2d(num_channels, feature_size, 4, 2, 1, bias = False),
        nn.BatchNorm2d(feature_size),
        nn.LeakyReLU(negative_slope = 0.2, inplace = True),

        # 128 -> 128
        nn.Conv2d(feature_size, feature_size, 4, 2, 1, bias = False),
        nn.BatchNorm2d(feature_size),
        nn.LeakyReLU(negative_slope = 0.2, inplace = True),

        # 128 -> 256
        nn.Conv2d(feature_size, feature_size*2, 4, 2, 1, bias = False),
        nn.BatchNorm2d(feature_size*2),
        nn.LeakyReLU(negative_slope = 0.2, inplace = True),

        # 256 -> 512
        nn.Conv2d(feature_size*2, feature_size*4, 4, 2, 1, bias = False),
        nn.BatchNorm2d(feature_size*4),
        nn.LeakyReLU(negative_slope = 0.2, inplace = True),

        # 512 -> 1024
        nn.Conv2d(feature_size*4, feature_size*8, 4, 2, 1, bias = False),
        nn.BatchNorm2d(feature_size*8),
        nn.LeakyReLU(negative_slope = 0.2, inplace = True),
    )

    # tạo một block để giảm chiều của text
    self.text_encoder = nn.Sequential(
        nn.Linear(in_features = embedding_size, out_features = reduced_dim_size),
        nn.BatchNorm1d(reduced_dim_size),
        nn.LeakyReLU(negative_slope = 0.2, inplace = True),
        )



    # tạo một Block cuối cùng để dự đoán kết quả 0,1
    self.final_layer = nn.Sequential(
        # (1024 + 256) -> 1
        nn.Conv2d(feature_size*8 + reduced_dim_size, 1, 4, 1, 0, bias = False),
        nn.Sigmoid()
    )

  def forward(self, img, text_embedding):
      text_encoder = self.text_encoder(text_embedding)  # shape: (batch_size, reduced_dim_size)
      #text_encoder = text_encoder.unsqueeze(2).unsqueeze(2)  # shape: (batch_size, reduced_dim_size, 1, 1)

      # Encoder for images
      img_encoder = self.img_encoder(img)  # shape: (batch_size, feature_size*8, 4, 4)

      # Get the spatial dimensions of img_encoder
      img_h, img_w = img_encoder.shape[2:]

      # Reshape text_encoder to have 4 dimensions and match spatial dimensions of img_encoder
      # by replicating it across the height and width dimensions
      # New shape: (batch_size, reduced_dim_size, img_h, img_w)
      replicated_text = text_encoder.repeat(img_h, img_w, 1, 1).permute(2, 3, 0, 1)

      # Now you can concatenate along the channel dimension (dim=1)
      concat_input = torch.cat([img_encoder, replicated_text], dim=1)
      x = self.final_layer(concat_input)
      return x.view(-1, 1), img_encoder

# %%
generator = Generator(100, 128, 3, 768, 256).to(device)

# %%
discriminator = Discriminator(3, 128, 768, 256).to(device)

# %% [markdown]
# ### plot hiển thị ảnh

# %%
# định nghĩa một hàm hiển thị ảnh sau mỗi lần train dữ liệu
import matplotlib.pyplot as plt
from torchvision.utils import make_grid
import numpy as np
import torchvision # Import torchvision

def show_grid(img):
  npimg = img.numpy()
  plt.imshow(np.transpose(npimg, (1, 2, 0)))
  plt.show()

show_grid(torchvision.utils.make_grid(ds[0]['image'], normalize = True))

# %%
def plot_output(generator, epoch, fixed_noise, plt_o_text_embeddings):
  plt.clf()  # xóa biểu đồ cũ
  with torch.no_grad():  # không có thực hiện gradient

    generator.eval()
    test_img = generator(fixed_noise.to(device), plt_o_text_embeddings.to(device))

    generator.train()
    grid = torchvision.utils.make_grid(test_img.cpu(), normalize=True)
    show_grid(grid)
    # Lưu hình ảnh với tên file chứa epoch
    plt.savefig(f'image_epoch_{epoch + 1}.png')

# %%
# mục đích của đoạn code này để đọc dữ liệu của một batch
batch_sample = next(iter(load_dataset))
batch_sample['image'].shape

# %%
show_grid(torchvision.utils.make_grid(batch_sample['image'], normalize = True))

# %% [markdown]
# ### Train model

# %%
plt_o_text_embeddings = ds[0]['encoded_caption']
print(plt_o_text_embeddings.shape)
plt_o_text_embeddings = plt_o_text_embeddings.unsqueeze(0)
print(plt_o_text_embeddings.shape)

# %%
latent_dim = 100
fixed_noise = torch.randn(size=(1, latent_dim))
print(fixed_noise.shape)

# %%
bce_loss = nn.BCELoss()
l2_loss = nn.MSELoss()
l1_loss = nn.L1Loss()

# %%
import torch.optim as optim

optimizer_G = optim.Adam(generator.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimizer_D = optim.Adam(discriminator.parameters(), lr=0.0002, betas=(0.5, 0.999))

# %%
import time

epochs = 500

for epoch in range(epochs):
    lambda_1 = 50
    lambda_2 = 100

    d_losses, g_losses = [], []

    epoch_time = time.time()

    for batch in load_dataset:
        running_D_loss = 0.0
        running_G_loss = 0.0

        real_imgs = batch['image'].to(device)
        embeded_text = batch['encoded_caption'].to(device)


        # labels
        real_labels = torch.ones(batch['image'].size(0),1, device = device)
        fake_labels = torch.zeros(batch['image'].size(0),1, device = device)

        # -------------------------- Train Disciminator ---
        optimizer_D.zero_grad()

        # Noise input for Disciminator
        noise = torch.randn((batch['image'].size(0), latent_dim)).to(device)
        fake_imgs = generator(noise, embeded_text)

        # tính toán real loss
        real_outputs, _ = discriminator(real_imgs, embeded_text)
        real_loss = bce_loss(real_outputs, real_labels)

        # tính toán fake loss
        fake_outputs, _ = discriminator(fake_imgs.detach(), embeded_text)
        fake_loss = bce_loss(fake_outputs, fake_labels)


        D_loss = real_loss + fake_loss
        d_losses.append(D_loss.item())

        # update weight
        D_loss.backward()
        optimizer_D.step()



        # -------------- Train Generator ---
        optimizer_G.zero_grad()

        # Noise input for Generator
        noise = torch.randn((batch['image'].size(0), latent_dim)).to(device)
        fake_imgs = generator(noise, embeded_text)

        # loss sau G
        l1_loss_value = l1_loss(real_imgs, fake_imgs)


        # fake_features: các features ảnh được tổng hợp lại cuối cùng
        fake_g_outputs, fake_features = discriminator(fake_imgs.detach(), embeded_text)
        _, real_features = discriminator(real_imgs, embeded_text)
        # tính trung bình các đặc trưng ảnh fake và ảnh real của 1 batch
        activation_fake = torch.mean(fake_features, dim = 0)
        activation_real = torch.mean(real_features, dim = 0)
        l2_loss_value = l2_loss(activation_fake, activation_real)

        # real loss sau D -> G (làm cho D tin rằng G tạo ra ảnh thật)
        real_loss = bce_loss(fake_g_outputs, real_labels)
        G_loss = real_loss + lambda_1*l1_loss_value + lambda_2*l2_loss_value



        GAN_loss = bce_loss(fake_g_outputs, real_labels)


        G_loss = GAN_loss + lambda_1*l1_loss_value + lambda_2*l2_loss_value
        g_losses.append(G_loss.item())

        # update weight
        G_loss.backward()
        optimizer_G.step()



    avg_d_loss = sum(d_losses)/len(d_losses)
    avg_g_loss = sum(g_losses)/len(g_losses)

    if (epoch+1) % 10 == 0:
        plot_output(generator, epoch, noise[0], embeded_text[0])


    print('Epoch [{}/{}] loss_D: {:.4f} loss_G: {:.4f} time: {:.2f}'.format(
        epoch+1, epochs,
        avg_d_loss,
        avg_g_loss,
        time.time() - epoch_time)
    )

# sau khi train xong ta save model lại
model_save_path = "./model_save"
torch.save(generator.state_dict(), os.path.join(model_save_path,'generator.pth'))
torch.save(discriminator.state_dict(), os.path.join(model_save_path,'discriminator.pth'))

# %% [markdown]
# ### Inference

# %%
generator.eval()

noise = torch.randn(size=(1, 100))
text_embedding = ds[10]['encoded_caption'].unsqueeze(0)

with torch.no_grad():
    test_images = generator(noise.to(device), text_embedding.to(device))
grid = torchvision.utils.make_grid(test_images.cpu(), normalize=True)
show_grid(grid)

# %% [markdown]
# ## Test

# %%
# Instead of trying to access elements directly like this:
# load_dataset[0]

# Use the following code to get the first batch from the DataLoader:
for batch in load_dataset:
    data = batch  # Access the data from the first batch
    break  # Exit the loop after getting the first batch

# Now you can access elements within the batch 'data' using indexing, for example:
image = data['image'][0]  # Get the first image from the batch
caption = data['caption'][0]  # Get the first caption from the batch

# %%
print(data['image'].shape)

# %%
embeded_text = data['encoded_caption'][0].unsqueeze(0).repeat(64,1)
print(embeded_text.shape)

# %%
noise = torch.randn((data['image'].shape[0], latent_dim), device = device)
print(noise.shape)

# %%
feature_size = 128
text_encoder = nn.Sequential(
        nn.Linear(embeded_text.shape[1], 256),
        nn.BatchNorm1d(256),
        nn.LeakyReLU(negative_slope = 0.2, inplace = True),
        nn.Linear(256, 256)
    ).to(device)

upsampling = nn.Sequential(
        # 100 + 256
        nn.ConvTranspose2d(noise.shape[1] + 256, feature_size*8, 4, 1, 0, bias = False),
        nn.BatchNorm2d(feature_size*8), # 1024
        nn.ReLU(inplace = True),

        # 1024 -> 512
        nn.ConvTranspose2d(feature_size*8, feature_size*4, 4, 2, 1, bias = False),
        nn.BatchNorm2d(feature_size*4), # 512
        nn.ReLU(inplace = True),

        # 512 -> 256
        nn.ConvTranspose2d(feature_size*4, feature_size*2, 4, 2, 1, bias = False),
        nn.BatchNorm2d(feature_size*2), # 256
        nn.ReLU(inplace = True),

        # 256 -> 128
        nn.ConvTranspose2d(feature_size*2, feature_size, 4, 2, 1, bias = False),
        nn.BatchNorm2d(feature_size), # 128
        nn.ReLU(inplace = True),

        # 128 -> 3
        nn.ConvTranspose2d(128, 3, 4, 2, 1, bias = False),
        nn.Tanh()
).to(device)
text_encoder.eval()
text_encoder = text_encoder(embeded_text)
# tạo một input có shape (batch_size, 256, 1, 1)
concat_input = torch.cat([noise, text_encoder], dim = 1).unsqueeze(2).unsqueeze(2)
output = upsampling(concat_input)

# %%
print(output.shape)

# %%
num_channels = 3
feature_size = 128
#negative_slope = 0.2
model_test = nn.Sequential(
        # 3 -> 128
        nn.Conv2d(num_channels, feature_size, 4, 2, 1, bias = False),
        nn.BatchNorm2d(feature_size),
        nn.LeakyReLU(negative_slope = 0.2, inplace = True),

        # 128 -> 128
        nn.Conv2d(feature_size, feature_size, 4, 2, 1, bias = False),
        nn.BatchNorm2d(feature_size),
        nn.LeakyReLU(negative_slope = 0.2, inplace = True),

        # 128 -> 256
        nn.Conv2d(feature_size, feature_size*2, 4, 2, 1, bias = False),
        nn.BatchNorm2d(feature_size*2),
        nn.LeakyReLU(negative_slope = 0.2, inplace = True),

        # 256 -> 512
        nn.Conv2d(feature_size*2, feature_size*4, 4, 2, 1, bias = False),
        nn.BatchNorm2d(feature_size*4),
        nn.LeakyReLU(negative_slope = 0.2, inplace = True),

        # 512 -> 1024
        nn.Conv2d(feature_size*4, feature_size*8, 4, 2, 1, bias = False),
        nn.BatchNorm2d(feature_size*8),
        nn.LeakyReLU(negative_slope = 0.2, inplace = True),
)

# %%
image_1 = data['encoded_caption']
fake_imgs = generator(noise.to(device), image_1.to(device))
print(fake_imgs.shape)

# %%
print(image_1.shape)

# %%
#image_1 = data['image'][0]
image_1 = data['encoded_caption']
fake_imgs = generator(noise.to(device), image_1.to(device))
print(fake_imgs.shape)
model_test = model_test.to(device)
image_1 = image_1.to(device)
image_1 = image_1.unsqueeze(0)
print(image_1.shape)
a = model_test(image_1)
print(a.shape)
